# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd/content/drive/MyDrive/ops2023
# Out:
# /content/drive/MyDrive/ops2023

# %%
pwd
# Out:
# '/content/drive/MyDrive/ops2023'

# %%
print("hello world")
# Out:
# hello world

# %%
for i in range(0,5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
